# %%
print("list:mutuablee(can be modified after decelared or create )")
print("list can store multiple type of data types")
print("can contain the duplicate element, ordered(maintain the order of element based on that how they...) , ")
print("general data,it is like pointer,it doesn't store the acutal value its working on memory, work on secondary memory in main memory it store the reference")

my_list=list((13,24,"jelel",5.3))
print(my_list)
# Out:
# list:mutuablee(can be modified after decelared or create )
# list can store multiple type of data types
# can contain the duplicate element, ordered(maintain the order of element based on that how they...) ,
# general data,it is like pointer,it doesn't store the acutal value its working on memory, work on secondary memory in main memory it store the reference
# [13, 24, 'jelel', 5.3]

# %%
print("tuple:-orderd but imutable means can't change after declared or created")
print("it can also store multiple type ofdata type")
print("read only")
my_tuple=(23,56,'kg')

# %%
print("disct: unordered and mutable ")
print(":it store data types in key value pair")
print("key value mapping ")
my_disct={'name':'nova','class':'ug','age':20}

# %%
print("array: mutable and it can only store the same type of element")
print("use cases: numerical calculation")
from array import array
a=array('i',[7,4,2])
