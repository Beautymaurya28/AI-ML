# %%
a = True
b = False
print(a + b)
# Out:
# 1

# %%
x = 3
y = 2
print(x / y, x // y, x % y)
# Out:
# 1.5 1 1

# %%
a="10"
b=float(a)
c=str(a)
d=bool(a)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
var="10"
var=int(var)+5
print(var)

# %%
x=10
y=20
x=x+y
y=x-y
x=x-y
print(x,y)
# Out:
# 20 10

# %%
x,y,z=1,2

# %%
a=b=c=5
a=a+2
print(a,b,c)
# Out:
# 7 5 5

# %%
a="5"
b=2
print(a*b)
# Out:
# 55

# %%
data=[1,2,3,4]
print(type(data))
# Out:
# <class 'list'>

# %%
x=5
y=2.0
z=x/y
print(z,type(z))
# Out:
# 2.5 <class 'float'>

# %%
my_age=21
print(f"i am {my_age} years old.")
# Out:
# i am 21 years old.

# %%
a=10
b=5
a=a+b #10+5
b=a-b #15-5=10
a=a-b #15-10 =5
print(a,b)
print(a)
# Out:
# 5 10
# 5

# %%
2name="Noova" #variables can't start with number and special char
print(2name)
