# %%
# write a to calculate the avg of 4 number using function
def avgs(a,b,c,d):
    avg=(a+b+c+d)/4
    print(f'The avg of four number is :{avg}')
    return avg

avgs(2,4,5,7)

# %%
# write a program to print hello on the output screen using function
def greet():
    return "hello"
greet()

# %%
def greet1(name):
    return f'Hello {name}'

greet1("Noova")

# %%
#calculate the area of circle using fucntion
def cir(radius):
    area=3.14*(radius**2)
    print(f'the area of circle is {area}')
    return area
rad=int(input("enter the radius of circle: "))
cir(rad)
# Out:
# the area of circle is 78.5
# 78.5

# %%
#to check number if prime or not
def check(num):
    if num>=1:
      for i in range(2, num):
        if num % i == 0:
           print("num is prime")
        else:
           print("num is not prime")
check(9)

# %%
#write a program to find a factorial of a number using function:
#default value in factorial is 0 and 1
# import math
# def factorial_recursion(num):
#     return math.factorial(num)
# factorial_recursion(5)


#second method
def fact(num):
    fact=1
    for i in range(1,num+1):
        fact*1
    return fact
fact(5)

def fact1(n):
    if n==1 or n==0:
        return 1
    else:
     return n*fact1(n-1)  
fact1(5)
# Out:
# 120

# %%
#write a program to calculate the maximum btw two number using fucntion
def maximum(num1,num2):
    if num1>num2:
        print("num1 is greater")
    else:
        print("num2 is greater")

num1=int(input("enter the num1:"))
num2=int(input("enter the num2:"))
maximum(num1,num2)
# Out:
# num2 is greater

# %%
# write a python program to manage student marks for different subjects:
# -1.create a function  add_student() to add a new student and their marks... 
# (store in a dictionary where keys are students names and values are lists of marks )
#-2.create a function calculate_average() to calculate each students average
#- 3.create a function find_topper() to display the student with the highest average
#- 4 allow the user to view, add ,and update marks using a simple menu loop.

# def stud_sys(name,marks):
#     name=input("enter the name of the student: ").strip()
#     if name in stud_sys:
#         print("name already exist")

students={}
def add_stud():
    name=input("Enter student name: ").strip().capitalize()
    #strip=it cleans upthe input for exampleif user type " noova" so it will remove the space and takeonly "noova" and without strip() name would include those spaces
    #capitalize()-make first letter uppercase(Its just for neatness and uniformaity so the names always start with a capital letter. )
    marks=list(map(float,input("enter marks seperated by space: ").split()))
    students[name]=marks
    print("Student added successfully!")

add_stud()
print(students)
# Out:
# Student added successfully!
# {'Vikash': [89.0, 98.0, 78.0]}

# %%
#Create a program that helps a group of field split their travel expenses.
#-use a function add_expense() to record who spent how much
#-store each expense as a tuple like ("ABC",1200)in a list.
#-write another function calculate_share() that devides the totak expense equally and tells who owes or get money back
