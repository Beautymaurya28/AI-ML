# %%
#intro of string
print("sequence of character enclosed within ")
a='beauty' #single qoutes string
a1="beauty"  #double qoutes string
a2="""beauty"""  #tripple qoutes string
print(a,a1,a2)


#how to find length of any string
nameshort=len(a2)
print(nameshort)
nameshort=a2[0:3]
print(nameshort)
character1=a2[1]
print(character1)
negative_indix=a1[-3:-1]
print(negative_indix)

#negative slicing
name="mourya"
print(name[-4:-1])
print(name[2:5])

word="amazing"
print(word[1:6:3])
print(word[0:])
print(word[:6])
#how to extract individual char from string
print("individual char from string")
mystr="my name is beauty"
print(mystr[0])

#string function
#1.length() function
a="beauty"
length=len(a)
print(length)

#2.string-endswith
print(a.endswith("ter"))  #it will give the false
name="beauty"
print(name.endswith("ty"))
#3.string-startswith
print(a.startswith("bea"))  #it will  give the true
#4.string.count("c")
string="abdkgjdfjigdjkld"
count=string.count("c")
print(count)

mystring="beaaaaauty"
count=mystring.count("a")
print(count)

#5.string.capitalize
captialize=mystring.capitalize()
print(captialize)

#6.string.upper
my="beauty"
print(my.upper())
upper=mystring.upper()
print(upper)

#6.string.lower
print(my.lower())
lower=mystring.lower()
print(lower)

#6.string.find(word)
mystring="hello world"
find=mystring.find("e")
print(find)

#6.string.replace(old word,new world)
mystring="hello world"
replace=mystring.replace("h","H")
print(replace)


#escape sequence chracter:
a="hello! i am beauty.\ncould i know about \"you\"?"
print(a)

#splitting a string
fruits="i like mangoes,appli,banana,grapes"
print(fruits.split(","))

# %%
#acess first and last char of a string
name=str(input("enter the string:"))
print("first and last char of string:",name[0],name[-1])
# Out:
# first and last char of string: b y

# %%
name1=str(input("enter the string"))
print("substring from 0 to 6",name1[0:3])
# Out:
# substring from 0 to 6 bea

# %%
##print character from string 
str1="python"
for ch in str1:
    print(ch,end=" ")
# Out:
# p y t h o n

# %%
## reverse the string at given slicing value
name2=str(input("enter the string:"))
reversed_name2=name2[3:-1]
print("reverse slicing:",reversed_name2)
# Out:
# reverse slicing: ut

# %%
##concatenation operator
str1="hello"
str2="world"
conact=str1+" "+str2
print("the merge is:",conact)
print("slicing merge",str1[1:3]+" "+str2[2:-2])



## repaet the string 
print("repeation:",conact*3)


##Membership operator
#1.in or not_in
print("is it or not:","hello" in conact)
print("not in check:","home" not in conact)


##slicing
str3="Learning"
print("every second char:",str3[::2])
print("revser of the string:",str3[::-1])
# Out:
# the merge is: hello world
# slicing merge el r
# repeation: hello worldhello worldhello world
# is it or not: True
# not in check: True
# every second char: Lann
# revser of the string: gninraeL

# %%
## there are total 47 method of string and it is immutable(we can't change or modify later once it is declared yess we can update)

#1.take string from user
str1=str(input("enter the string:"))
print("orginal string:",str1)

#2.convert into lowercase
print("lowecase:",str1.lower())
print("upper case:",str1.upper())
# Out:
# orginal string: Beauty
# lowecase: beauty
# upper case: BEAUTY

# %%
#1.convert upper and lower
name=str(input("enter your name plz:"))
print("orginal name:",name)
print("lower:",name.lower())
print("upper:",name.upper())


#2.start with particular methodor not
print("check:",name.startswith("Beauty"))

#3.count
text="Python is easy python lan"
print("occrance:",name.count("python"))
print("char occurance:",text.count("P"))


#program to find index
print("the index:",text.index("p"))
print("striping",name.strip())
print("join:",name.join("HII"))

#remove leading and trailing space
print("Stripped:",text.strip())

#replace a world 
print("Replace spaces with '_':",name.replace(" ","_"))

#split into words
print("splitting:",name.split())

# %%
user=str(input("enter the string: "))
print(user)
print("user string first letter: ",user[0])
user1=str(input("enter the word:"))
print("from 0 to 6: ",user[0:6])
print("from 4 to end: ",user1[4::])
user_length=len(user1)
print("the length of the string is: ",user_length)
for ch in user1:
    print(ch,end=" ")

# %%
str1=str(input("enter the string1: "))
str2=str(input("enter the string 2: "))
print("the concatenates of both string is: ",str1+str2)
str3=str(input("enter the string third: "))
print("repetition of string 3 times: ",str3*3)
str4=str(input("enter the string: "))
print("find words: ",str4.find("Intel"))

str5=str(input("enter the string: "))
every_second=str5[1::2]
reversed=every_second[::-1]
print("every second char in string is:  ",every_second)
print("reverse order: ",reversed)

# %%
str1=str(input("enter the string: "))
split_word=str1.split()
firs_char=split_word[0]
print(split_word)
print(firs_char)
# Out:
# ['Python', 'is', 'Powerful']
# Python

# %%
str1=str(input("enter the string:"))
split_word=str1.split()
print(len(split_word))
s = "programming"
result = ""

for ch in s:
    if ch not in result:
        result += ch

print(result) 

# result="".join(set(s))
# print(result)
# Out:
# 5
# progamin
# oangipmr

# %%
str1="NoovaHub"
print("substring(0 to 6):",str1[0:5])
print("substring (from to end): ",str1[4:])

# %%
## write a prgram to create a string .....
str1="Pyhton is easy to Learn"
print("putput: ",str1)

# %%
str1=str(input("enter your name: "))
print("substring: ",str1[0],str1[-1])

# %%
str1="pyhton is easy to learn"
print("substring: ",str1[4:9])
print("subsring",str1[-3],str1[0])

# %%
str1="Welcome to python hub"
print("created string: ",str1[-5],str1[0],str1)

# %%
str1 = input("Enter the string: ")
vowel = "aeiouAEIOU"

if str1[0] in vowel and str1[-1].isdigit() and any(ch.isupper() for ch in str1):
    print("Yes, it starts with a vowel, ends with a digit, and has at least one uppercase letter.")
else:
    print("No, it does not satisfy all three conditions.")
# Out:
# Yes, it starts with a vowel, ends with a digit, and has at least one uppercase letter.
